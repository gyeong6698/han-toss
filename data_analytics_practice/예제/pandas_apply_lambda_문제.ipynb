# %% [markdown]
# ## pandas_apply_lambda

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [23, 35, 45, 28, 34],
    'Salary': [70000, 80000, 120000, 90000, 110000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary
# 0    Alice   23   70000
# 1      Bob   35   80000
# 2  Charlie   45  120000
# 3    David   28   90000
# 4      Eva   34  110000

# %% [markdown]
# ## 문제 1.
# - 각 연봉을 10%씩 증가

# %%
df['Salary'] = df['Salary']*1.1
print(df)
# Out:
#       Name  Age    Salary
# 0    Alice   23   92400.0
# 1      Bob   35  105600.0
# 2  Charlie   45  158400.0
# 3    David   28  118800.0
# 4      Eva   34  145200.0

# %% [markdown]
# ## 문제 2.
# - 사람들을 나이 기준으로 범주화

# %%
df['Age Group'] = df['Age Group'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\han-toss\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age Group'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df['Age Group'] = df['Age Group'].value_counts()
#
# File ~\Desktop\han-toss\venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\Desktop\han-toss\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Age Group'

# %% [markdown]
# ## 문제 3.
# - Age와 Salary의 곱을 계산하여 Age_Salary로 계산

# %%
df['Age_Salary'] =
# Out:
#       Name  Age    Salary Age Group  Age_Salary
# 0    Alice   23   93170.0     Young   2142910.0
# 1      Bob   35  106480.0       Old   3726800.0
# 2  Charlie   45  159720.0       Old   7187400.0
# 3    David   28  119790.0     Young   3354120.0
# 4      Eva   34  146410.0       Old   4977940.0

# %% [markdown]
# ## 문제 4.
# - 각 이름의 첫 글자를 추출

# %%
df['Initial'] = # code
# Out:
#       Name  Age    Salary Age Group  Age_Salary Initial
# 0    Alice   23   93170.0     Young   2142910.0       A
# 1      Bob   35  106480.0       Old   3726800.0       B
# 2  Charlie   45  159720.0       Old   7187400.0       C
# 3    David   28  119790.0     Young   3354120.0       D
# 4      Eva   34  146410.0       Old   4977940.0       E

# %% [markdown]
# ## 문제 5.
# - 함수를 정의하고 apply와 함께 사용

# %%
def categorize_salary(salary):
    if salary > 100000:
        return 'High'
    else:
        return 'Low'

# code
# Out:
#       Name  Age    Salary Age Group  Age_Salary Initial Salary Category
# 0    Alice   23   93170.0     Young   2142910.0       A             Low
# 1      Bob   35  106480.0       Old   3726800.0       B            High
# 2  Charlie   45  159720.0       Old   7187400.0       C            High
# 3    David   28  119790.0     Young   3354120.0       D            High
# 4      Eva   34  146410.0       Old   4977940.0       E            High

# %% [markdown]
# ## 문제 6.
# - 나이가 30이상이면 연봉에 보너스 추가 보너스 비율 0.5%

# %%
df['Bonus Salary'] = # code
# Out:
#       Name  Age    Salary Age Group  Age_Salary Initial Salary Category  \
# 0    Alice   23   93170.0     Young   2142910.0       A             Low
# 1      Bob   35  106480.0       Old   3726800.0       B            High
# 2  Charlie   45  159720.0       Old   7187400.0       C            High
# 3    David   28  119790.0     Young   3354120.0       D            High
# 4      Eva   34  146410.0       Old   4977940.0       E            High
#
#    Bonus Salary  Average_Age_Salary
# 0       93170.0            139755.0
# 1       53240.0            133100.0
# 2       79860.0            199650.0
# 3      119790.0            179685.0
# 4       73205.0            183012.5

# %% [markdown]
# ## 문제 7.
# - Salary + Bonus Salary의 평균을 계산.

# %%
df['Average_Age_Salary'] = # code
# Out:
#       Name  Age    Salary Age Group  Age_Salary Initial Salary Category  \
# 0    Alice   23   93170.0     Young   2142910.0       A             Low
# 1      Bob   35  106480.0       Old   3726800.0       B            High
# 2  Charlie   45  159720.0       Old   7187400.0       C            High
# 3    David   28  119790.0     Young   3354120.0       D            High
# 4      Eva   34  146410.0       Old   4977940.0       E            High
#
#    Bonus Salary  Average_Age_Salary
# 0       93170.0            139755.0
# 1       53240.0            133100.0
# 2       79860.0            199650.0
# 3      119790.0            179685.0
# 4       73205.0            183012.5
